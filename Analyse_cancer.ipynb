# %% [markdown]
# <a href="https://colab.research.google.com/github/asmazarour18-sys/gitcolab/blob/main/Analyse_cancer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sns.countplot(x="pathologic_stage", data=df)
plt.title("Distribution des stades tumoraux")
plt.xlabel("Stade")
plt.ylabel("Nombre de patientes")
plt.xticks(rotation=45)
plt.show()
